# %%
# !pip install igor2
# Out:
# Collecting igor2
#   Downloading igor2-0.5.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.19.2 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from igor2) (1.26.4)
# Downloading igor2-0.5.9-py3-none-any.whl (32 kB)
# Installing collected packages: igor2
# Successfully installed igor2-0.5.9

# %%
# !pip install SciFiReaders
# Out:
# Collecting SciFiReaders
#   Downloading SciFiReaders-0.11.6-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: setuptools in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from SciFiReaders) (75.1.0)
# Requirement already satisfied: numpy in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from SciFiReaders) (1.26.4)
# Collecting toolz (from SciFiReaders)
#   Downloading toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting cytoolz (from SciFiReaders)
#   Downloading cytoolz-1.0.1-cp310-cp310-win_amd64.whl.metadata (4.7 kB)
# Collecting dask>=2.20.0 (from SciFiReaders)
#   Downloading dask-2024.12.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting sidpy>=0.11.2 (from SciFiReaders)
#   Downloading sidpy-0.12.3-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: ipython>=7.1.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from SciFiReaders) (8.27.0)
# Collecting pyUSID (from SciFiReaders)
#   Downloading pyUSID-0.0.12-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting gdown (from SciFiReaders)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting mrcfile (from SciFiReaders)
#   Downloading mrcfile-1.5.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting numba>=0.59.0rc1 (from SciFiReaders)
#   Downloading numba-0.61.0rc1-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: click>=8.1 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from dask>=2.20.0->SciFiReaders) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from dask>=2.20.0->SciFiReaders) (3.0.0)
# Collecting fsspec>=2021.09.0 (from dask>=2.20.0->SciFiReaders)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from dask>=2.20.0->SciFiReaders) (24.1)
# Collecting partd>=1.4.0 (from dask>=2.20.0->SciFiReaders)
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from dask>=2.20.0->SciFiReaders) (6.0.2)
# Requirement already satisfied: importlib_metadata>=4.13.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from dask>=2.20.0->SciFiReaders) (8.5.0)
# Requirement already satisfied: decorator in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (5.14.3)
# Requirement already satisfied: exceptiongroup in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (4.11.0)
# Requirement already satisfied: colorama in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipython>=7.1.0->SciFiReaders) (0.4.6)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.59.0rc1->SciFiReaders)
#   Downloading llvmlite-0.44.0rc2-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Collecting h5py>=2.6.0 (from sidpy>=0.11.2->SciFiReaders)
#   Downloading h5py-3.12.1-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from sidpy>=0.11.2->SciFiReaders) (3.5.3)
# Collecting distributed>=2.0.0 (from sidpy>=0.11.2->SciFiReaders)
#   Downloading distributed-2024.12.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: psutil in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from sidpy>=0.11.2->SciFiReaders) (5.9.0)
# Requirement already satisfied: six in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from sidpy>=0.11.2->SciFiReaders) (1.16.0)
# Collecting joblib>=0.11.0 (from sidpy>=0.11.2->SciFiReaders)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ipywidgets (from sidpy>=0.11.2->SciFiReaders)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: ipykernel in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from sidpy>=0.11.2->SciFiReaders) (6.29.5)
# Collecting scikit-learn (from sidpy>=0.11.2->SciFiReaders)
#   Downloading scikit_learn-1.6.0-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: scipy in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from sidpy>=0.11.2->SciFiReaders) (1.14.1)
# Collecting ase (from sidpy>=0.11.2->SciFiReaders)
#   Downloading ase-3.23.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting ipympl (from sidpy>=0.11.2->SciFiReaders)
#   Downloading ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from gdown->SciFiReaders) (4.12.3)
# Requirement already satisfied: filelock in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from gdown->SciFiReaders) (3.16.1)
# Requirement already satisfied: requests[socks] in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from gdown->SciFiReaders) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from gdown->SciFiReaders) (4.67.1)
# Requirement already satisfied: pillow in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from pyUSID->SciFiReaders) (11.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders) (3.1.4)
# Collecting locket>=1.0.0 (from distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders)
#   Using cached locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting msgpack>=1.0.2 (from distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders)
#   Downloading msgpack-1.1.0-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders) (2.4.0)
# Collecting tblib>=1.6.0 (from distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders)
#   Using cached tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders) (2.1.0)
# Collecting zict>=3.0.0 (from distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders)
#   Using cached zict-3.0.0-py2.py3-none-any.whl.metadata (899 bytes)
# Requirement already satisfied: zipp>=3.20 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from importlib_metadata>=4.13.0->dask>=2.20.0->SciFiReaders) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from jedi>=0.16->ipython>=7.1.0->SciFiReaders) (0.8.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.11.2->SciFiReaders) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.11.2->SciFiReaders) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.11.2->SciFiReaders) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.11.2->SciFiReaders) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.11.2->SciFiReaders) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.1.0->SciFiReaders) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from beautifulsoup4->gdown->SciFiReaders) (2.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipykernel->sidpy>=0.11.2->SciFiReaders) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipykernel->sidpy>=0.11.2->SciFiReaders) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipykernel->sidpy>=0.11.2->SciFiReaders) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipykernel->sidpy>=0.11.2->SciFiReaders) (5.7.2)
# Requirement already satisfied: nest-asyncio in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipykernel->sidpy>=0.11.2->SciFiReaders) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipykernel->sidpy>=0.11.2->SciFiReaders) (25.1.2)
# Requirement already satisfied: ipython-genutils in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from ipympl->sidpy>=0.11.2->SciFiReaders) (0.2.0)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->sidpy>=0.11.2->SciFiReaders)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->sidpy>=0.11.2->SciFiReaders)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from requests[socks]->gdown->SciFiReaders) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from requests[socks]->gdown->SciFiReaders) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from requests[socks]->gdown->SciFiReaders) (2024.8.30)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown->SciFiReaders)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sidpy>=0.11.2->SciFiReaders)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: executing in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from stack-data->ipython>=7.1.0->SciFiReaders) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from stack-data->ipython>=7.1.0->SciFiReaders) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from stack-data->ipython>=7.1.0->SciFiReaders) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from jinja2>=2.10.3->distributed>=2.0.0->sidpy>=0.11.2->SciFiReaders) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->sidpy>=0.11.2->SciFiReaders) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\alexa\anaconda3\envs\py3_cellsam\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->sidpy>=0.11.2->SciFiReaders) (305.1)
# Downloading SciFiReaders-0.11.6-py2.py3-none-any.whl (84 kB)
# Downloading dask-2024.12.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 31.4 MB/s eta 0:00:00
# Downloading numba-0.61.0rc1-cp310-cp310-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 32.9 MB/s eta 0:00:00
# Downloading sidpy-0.12.3-py2.py3-none-any.whl (102 kB)
# Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
# Downloading cytoolz-1.0.1-cp310-cp310-win_amd64.whl (363 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading mrcfile-1.5.3-py2.py3-none-any.whl (44 kB)
# Downloading pyUSID-0.0.12-py2.py3-none-any.whl (69 kB)
# Downloading distributed-2024.12.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 47.5 MB/s eta 0:00:00
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading h5py-3.12.1-cp310-cp310-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 3.0/3.0 MB 35.0 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading llvmlite-0.44.0rc2-cp310-cp310-win_amd64.whl (30.3 MB)
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ------ --------------------------------- 5.2/30.3 MB 29.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 8.1/30.3 MB 20.2 MB/s eta 0:00:02
#    --------------- ------------------------ 11.8/30.3 MB 18.9 MB/s eta 0:00:01
#    ------------------------ --------------- 18.9/30.3 MB 22.9 MB/s eta 0:00:01
#    ------------------------------------- -- 28.6/30.3 MB 27.9 MB/s eta 0:00:01
#    ---------------------------------------  30.1/30.3 MB 28.1 MB/s eta 0:00:01
#    ---------------------------------------- 30.3/30.3 MB 22.6 MB/s eta 0:00:00
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading ase-3.23.0-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 28.1 MB/s eta 0:00:00
# Downloading ipympl-0.9.4-py3-none-any.whl (516 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading scikit_learn-1.6.0-cp310-cp310-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------  11.0/11.1 MB 68.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 38.6 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Downloading msgpack-1.1.0-cp310-cp310-win_amd64.whl (74 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached tblib-3.0.0-py3-none-any.whl (12 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 22.3 MB/s eta 0:00:00
# Using cached zict-3.0.0-py2.py3-none-any.whl (43 kB)
# Installing collected packages: zict, widgetsnbextension, toolz, threadpoolctl, tblib, PySocks, msgpack, mrcfile, locket, llvmlite, jupyterlab-widgets, joblib, h5py, fsspec, scikit-learn, partd, numba, cytoolz, gdown, dask, ase, ipywidgets, distributed, ipympl, sidpy, pyUSID, SciFiReaders
# Successfully installed PySocks-1.7.1 SciFiReaders-0.11.6 ase-3.23.0 cytoolz-1.0.1 dask-2024.12.0 distributed-2024.12.0 fsspec-2024.10.0 gdown-5.2.0 h5py-3.12.1 ipympl-0.9.4 ipywidgets-8.1.5 joblib-1.4.2 jupyterlab-widgets-3.0.13 llvmlite-0.44.0rc2 locket-1.0.0 mrcfile-1.5.3 msgpack-1.1.0 numba-0.61.0rc1 partd-1.4.2 pyUSID-0.0.12 scikit-learn-1.6.0 sidpy-0.12.3 tblib-3.0.0 threadpoolctl-3.5.0 toolz-1.0.0 widgetsnbextension-4.0.13 zict-3.0.0

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os
import SciFiReaders
import glob
from scipy.optimize import curve_fit

# %%
ibw_file = "C:/Users/alexa/Downloads/Image_10um_01.ibw"

# %%
reader = SciFiReaders.IgorIBWReader(ibw_file)
data = reader.read()

# %%
print(data)

height = data['Channel_000']

print('')
print(type(height))
img = np.array(height)

plt.imshow(img, cmap='gray')
# Out:
# {'Channel_000': sidpy.Dataset of type IMAGE with:
#  dask.array<array, shape=(256, 256), dtype=float32, chunksize=(256, 256), chunktype=numpy.ndarray>
#  data contains: HeightRetrace (m)
#  and Dimensions:
# x:  x (m) of size (256,)
# y:  y (m) of size (256,), 'Channel_001': sidpy.Dataset of type IMAGE with:
#  dask.array<array, shape=(256, 256), dtype=float32, chunksize=(256, 256), chunktype=numpy.ndarray>
#  data contains: DeflectionRetrace (m)
#  and Dimensions:
# x:  x (m) of size (256,)
# y:  y (m) of size (256,), 'Channel_002': sidpy.Dataset of type IMAGE with:
#  dask.array<array, shape=(256, 256), dtype=float32, chunksize=(256, 256), chunktype=numpy.ndarray>
#  data contains: ZSensorRetrace (m)
#  and Dimensions:
# x:  x (m) of size (256,)
# y:  y (m) of size (256,)}
#
# <class 'sidpy.sid.dataset.Dataset'>

# %% [markdown]
# # Segmenting normalised image

# %%
from cellSAM import segment_cellular_image

img = np.array(height)
img = (img-np.min(img))/np.ptp(img)
print(np.min(img), np.max(img))
mask, embedding, bounding_boxes = segment_cellular_image(img)
plt.matshow(mask)
# Out:
# 0.0 1.0

# %%
plt.matshow(mask)
plt.savefig("C:/Users/alexa/Downloads/mask.png")

# %% [markdown]
# # Selecting samples from grains of different sizes

# %%
from scipy.ndimage import center_of_mass

# Find the sizes of the different particles
sizes = np.zeros(np.max(mask)+1)

for ii in range(np.max(mask)+1):
    sizes[ii] = np.count_nonzero(mask==ii)

# Remove the zeroth element (the background)
sizes_new = sizes[1:]

# Bin these clusters by size
bins = 20
hist = np.histogram(sizes_new, bins=bins)
bin_boundaries = hist[1]

# Find the corresponding indices
size_args = []

for ii in range(bins):
    bounds = (bin_boundaries[ii], bin_boundaries[ii+1])
    bool_arr = np.array([sizes_new>=bounds[0], sizes_new<bounds[1]])
    size_args.append(list(np.argwhere(bool_arr.all(0)).T[0]))

# Take samples from each bin
no_of_samples = 3
sample_list = []

for ii in range(bins):
    #print(ii)
    if len(size_args[ii])>no_of_samples:
        sample_list.append(list(np.random.choice(size_args[ii], size=3, replace=False)))
    else:
        sample_list.append(size_args[ii])

# Find the pixel co-ordinates of these samples
coords = []

for ii in range(bins):
    sl = sample_list[ii]
    coord_ii = []
    for jj in range(len(sl)):
        mask_ii = mask==(ii+1) # +1 needed because we subtracted the zeroth element earlier
        coord_ii.append(center_of_mass(mask_ii))
    coords.append(coord_ii)

# %% [markdown]
# # Selecting areas with numerous grain boundaries (edges in the mask)

# %%
from scipy import signal

# Common edge detection method for grayscale images (perfect for this)
roll_up = np.roll(mask, 1, axis=0)
roll_down = np.roll(mask, -1, axis=0)
roll_left = np.roll(mask, 1, axis=1)
roll_right = np.roll(mask, -1, axis=1)

up = (mask==roll_up).astype(int)
down = (mask==roll_down).astype(int)
left = (mask==roll_left).astype(int)
right = (mask==roll_right).astype(int)

edges = up*down*left*right
plt.matshow(edges)

# Convolve kernel with edges to find regions with highest density of boundaries
ks = 10 # kernel size
kernel2d = np.ones((ks,ks))

boundary_density = signal.convolve2d(mask, kernel2d, mode='same', boundary='fill')
plt.matshow(boundary_density)

# Generate scan target coordinates
scan_size = 10
n_targets = 10

target_map = boundary_density.copy()

coords = np.zeros((n_targets, 2))

for ii in range(n_targets):
    coord = np.unravel_index(np.argmax(target_map), target_map.shape) # Find maximum density of boundaries in the current target map
    x_min = np.max((int(coord[1]-scan_size/2), 0))
    x_max = np.min((int(coord[1]+scan_size/2), target_map.shape[1]))
    y_min = np.max((int(coord[0]-scan_size/2), 0))
    y_max = np.min((int(coord[0]+scan_size/2), target_map.shape[1]))
    target_map[y_min:y_max, x_min:x_max] = 0 # Block out an area of scan_size**2 around to stop repeat imaging of the same region.

    coords[ii] = coord

print(coords)
plt.matshow(target_map)
# Out:
# [[170. 200.]
#  [160.  84.]
#  [ 17.  74.]
#  [139.  89.]
#  [ 77. 131.]
#  [198.  74.]
#  [ 26. 131.]
#  [105. 174.]
#  [ 94. 104.]
#  [156. 181.]]
